# %%
import numpy as np
import sympy
from sympy.abc import alpha, x, y, z, v, w, R, theta
from sympy import symbols, Matrix

# %%
px = symbols('p_{x}')
py = symbols('p_{y}')
pz = symbols('p_{z}')

yaw = symbols('yaw')
pitch = symbols('pitch')

v = symbols('v')
w_xy = symbols('w_xy')
w_z = symbols('w_z')
dt = symbols('dt')
